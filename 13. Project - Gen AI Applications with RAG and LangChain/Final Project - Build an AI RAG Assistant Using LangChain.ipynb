# %% [markdown]
# # Task 1: Load Document using LangChain for different sources

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_path = "A_Comprehensive_Review_of_Low_Rank_Adaptation_in_Large_Language_Models_for_Efficient_Parameter_Tuning-1.pdf" 

try:
    loader = PyPDFLoader(file_path=pdf_path)

    documents = loader.load()

    print(f"Successfully loaded {len(documents)} pages from the PDF.")
    for i, doc in enumerate(documents[:2]): 
        print(f"\n--- Page {i+1} ---")
        print(doc.page_content[:500]) 
except Exception as e:
    print(f"Error loading PDF: {e}")
# Out:
# Successfully loaded 11 pages from the PDF.
#
# --- Page 1 ---
# A Comprehensive Review of Low-Rank
# Adaptation in Large Language Models for
# Efficient Parameter Tuning
# September 10, 2024
# Abstract
# Natural Language Processing (NLP) often involves pre-training large
# models on extensive datasets and then adapting them for specific tasks
# through fine-tuning. However, as these models grow larger, like GPT-3
# with 175 billion parameters, fully fine-tuning them becomes computa-
# tionally expensive. We propose a novel method called LoRA (Low-Rank
# Adaptation) that signifi
#
# --- Page 2 ---
# model depth or reducing the usable sequence length. Furthermore, these meth-
# ods typically do not perform as well as full fine-tuning, leading to a trade-off
# between efficiency and model performance.
# Inspired by prior works that demonstrate over-parametrized models often
# reside in a low intrinsic dimensional space, we hypothesize that weight changes
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

# Path to your PDF document
pdf_path = "A_Comprehensive_Review_of_Low_Rank_Adaptation_in_Large_Language_Models_for_Efficient_Parameter_Tuning-1.pdf"

loader = PyPDFLoader(file_path=pdf_path)
documents = loader.load()

# %%
documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2024-09-10T21:50:42+00:00', 'moddate': '2024-09-10T21:50:42+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'A_Comprehensive_Review_of_Low_Rank_Adaptation_in_Large_Language_Models_for_Efficient_Parameter_Tuning-1.pdf', 'total_pages': 11, 'page': 0, 'page_label': '1'}, page_content='A Comprehensive Review of Low-Rank\nAdaptation in Large Language Models for\nEfficient Parameter Tuning\nSeptember 10, 2024\nAbstract\nNatural Language Processing (NLP) often involves pre-training large\nmodels on extensive datasets and then adapting them for specific tasks\nthrough fine-tuning. However, as these models grow larger, like GPT-3\nwith 175 billion parameters, fully fine-tuning them becomes computa-\ntionally expensive. We propose a novel method called LoRA (Low-Rank\nAdaptation) that significantly reduces the o
# ...

# %% [markdown]
# # Task 2: Apply text splitting techniques

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    separators=["\n\n", "\n", " ", ""] 
)

try:
    split_documents = text_splitter.split_documents(documents)

    print(f"Original number of documents (pages): {len(documents)}")
    print(f"Number of chunks after splitting: {len(split_documents)}")

    for i, chunk in enumerate(split_documents[:3]):
        print(f"\n--- Chunk {i+1} ---")
        print(chunk.page_content[:300]) 
        print(f"Metadata: {chunk.metadata}")
        
except NameError:
    print("Please ensure 'documents' variable is defined by running Task 1's code first.")
except Exception as e:
    print(f"Error splitting text: {e}")
# Out:
# Original number of documents (pages): 11
# Number of chunks after splitting: 38
#
# --- Chunk 1 ---
# A Comprehensive Review of Low-Rank
# Adaptation in Large Language Models for
# Efficient Parameter Tuning
# September 10, 2024
# Abstract
# Natural Language Processing (NLP) often involves pre-training large
# models on extensive datasets and then adapting them for specific tasks
# through fine-tuning. However, a
# Metadata: {'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2024-09-10T21:50:42+00:00', 'moddate': '2024-09-10T21:50:42+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'A_Comprehensive_Review_of_Low_Rank_Adaptation_in_Large_Language_Models_for_Efficient_Parameter_Tuning-1.pdf', 'total_pages': 11, 'page': 0, 'page_label': '1'}
#
# --- Chunk 2 ---
# BERTa, GPT-2, and GPT-3. Unlike other methods, LoRA introduces
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Assume 'documents' are loaded from Task 1
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
)

split_documents = text_splitter.split_documents(documents)

# %%
split_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'TeX', 'creationdate': '2024-09-10T21:50:42+00:00', 'moddate': '2024-09-10T21:50:42+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.26 (TeX Live 2024) kpathsea version 6.4.0', 'trapped': '/False', 'source': 'A_Comprehensive_Review_of_Low_Rank_Adaptation_in_Large_Language_Models_for_Efficient_Parameter_Tuning-1.pdf', 'total_pages': 11, 'page': 0, 'page_label': '1'}, page_content='A Comprehensive Review of Low-Rank\nAdaptation in Large Language Models for\nEfficient Parameter Tuning\nSeptember 10, 2024\nAbstract\nNatural Language Processing (NLP) often involves pre-training large\nmodels on extensive datasets and then adapting them for specific tasks\nthrough fine-tuning. However, as these models grow larger, like GPT-3\nwith 175 billion parameters, fully fine-tuning them becomes computa-\ntionally expensive. We propose a novel method called LoRA (Low-Rank\nAdaptation) that significantly reduces the o
# ...

# %% [markdown]
# # Task 3: Embed documents

# %%
from langchain_ibm import WatsonxLLMEmbeddings
from ibm_watson_machine_learning.foundation_models.utils.enums import EmbeddingTypes

api_key = "YOUR_WATSONX_API_KEY"
project_id = "YOUR_WATSONX_PROJECT_ID"
url = "https://us-south.ml.cloud.ibm.com" 

try:
    embeddings_model = WatsonxLLMEmbeddings(
        model_id=EmbeddingTypes.EMBEDDING_ENGLISH_V1, 
        url=url,
        project_id=project_id,
        api_key=api_key
    )
    
    print("Generating embeddings for document chunks...")
    document_embeddings = embeddings_model.embed_documents([doc.page_content for doc in split_documents])

    print(f"Generated embeddings for {len(document_embeddings)} chunks.")
    print(f"Dimension of each embedding vector: {len(document_embeddings[0])}")
except NameError:
    print("Please ensure 'split_documents' variable is defined by running Task 2's code first.")
except Exception as e:
    print(f"Error embedding documents: {e}")

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

# Initialize the Hugging Face embeddings model
embeddings_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %% [markdown]
# # Task 4: Create and Configure Vector Databases to Store Embeddings

# %%
from langchain_community.vectorstores import Chroma
from langchain_ibm import WatsonxLLMEmbeddings
from ibm_watson_machine_learning.foundation_models.utils.enums import EmbeddingTypes
import os

# Define a directory to persist your Chroma database
persist_directory = "./chroma_db"

try:
    vectordb = Chroma.from_documents(
        documents=split_documents,
        embedding=embeddings_model,
        persist_directory=persist_directory
    )

    vectordb.persist()
    print(f"Chroma DB created and persisted to {persist_directory}")

except NameError:
    print("Please ensure 'split_documents' and 'embeddings_model' variables are defined.")
except Exception as e:
    print(f"Error creating/configuring vector database: {e}")

# %%
from langchain_community.vectorstores import Chroma

persist_directory = "./chroma_db_huggingface"

vectordb = Chroma.from_documents(
    documents=split_documents,
    embedding=embeddings_model,
    persist_directory=persist_directory
)

vectordb.persist()

# %% [markdown]
# # Task 5: Develop a retriever to fetch document segments based on queries

# %%
from langchain_community.vectorstores import Chroma
from langchain_ibm import WatsonxLLMEmbeddings
from ibm_watson_machine_learning.foundation_models.utils.enums import EmbeddingTypes

api_key = "YOUR_WATSONX_API_KEY"
project_id = "YOUR_WATSONX_PROJECT_ID"
url = "https://us-south.ml.cloud.ibm.com"
embeddings_model = WatsonxLLMEmbeddings(model_id=EmbeddingTypes.EMBEDDING_ENGLISH_V1, url=url, project_id=project_id, api_key=api_key)
persist_directory = "./chroma_db"

try:
    vectordb = Chroma(
        persist_directory=persist_directory,
        embedding_function=embeddings_model 
    )

    retriever = vectordb.as_retriever(search_kwargs={"k": 3})

    print("Retriever successfully created from the vector database.")

    query = "What is the main topic discussed in the documents?"
    print(f"\nSearching for documents related to: '{query}'")
    retrieved_docs = retriever.invoke(query)

    print(f"Found {len(retrieved_docs)} relevant documents:")
    for i, doc in enumerate(retrieved_docs):
        print(f"\n--- Retrieved Document {i+1} ---")
        print(doc.page_content[:500]) 
        print(f"Source: {doc.metadata.get('source', 'N/A')}, Page: {doc.metadata.get('page', 'N/A')}")

except NameError:
    print("Please ensure 'embeddings_model' and 'persist_directory' are defined and Chroma DB is populated.")
except Exception as e:
    print(f"Error developing retriever or performing search: {e}")

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
persist_directory = "./chroma_db_huggingface"

vectordb = Chroma(
    persist_directory=persist_directory,
    embedding_function=embeddings_model
)

retriever = vectordb.as_retriever(search_kwargs={"k": 3})

# %% [markdown]
# # Task 6: Construct a QA Bot that Leverages the LangChain and LLM to Answer Questions

# %%
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_ibm import WatsonxLLMEmbeddings, WatsonxLLM
from ibm_watson_machine_learning.foundation_models.utils.enums import EmbeddingTypes, ModelTypes
from langchain_community.vectorstores import Chroma
from langchain.chains import RetrievalQA
import gradio as gr

os.environ["WATSONX_API_KEY"] = "YOUR_WATSONX_API_KEY"
os.environ["WATSONX_PROJECT_ID"] = "YOUR_WATSONX_PROJECT_ID"
watsonx_url = "https://us-south.ml.cloud.ibm.com" 

qa_chain = None
embeddings_model = None
vector_db_persist_dir = "./chroma_db_qa_bot"

def initialize_components(pdf_file_path):
    global qa_chain, embeddings_model

    if not pdf_file_path:
        return "Please upload a PDF file."

    try:
        # 1. Load document
        print(f"Loading PDF from: {pdf_file_path}")
        loader = PyPDFLoader(file_path=pdf_file_path)
        documents = loader.load()

        # 2. Apply text splitting
        print("Splitting documents...")
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=1000,
            chunk_overlap=200,
            separators=["\n\n", "\n", " ", ""]
        )
        split_documents = text_splitter.split_documents(documents)
        print(f"Split into {len(split_documents)} chunks.")

        # 3. Embed documents
        print("Initializing embedding model...")
        embeddings_model = WatsonxLLMEmbeddings(
            model_id=EmbeddingTypes.EMBEDDING_ENGLISH_V1,
            url=watsonx_url,
            project_id=os.environ["WATSONX_PROJECT_ID"],
            api_key=os.environ["WATSONX_API_KEY"]
        )

        # 4. Create and configure vector database
        print("Creating/loading Chroma DB...")
        if os.path.exists(vector_db_persist_dir):
            import shutil
            shutil.rmtree(vector_db_persist_dir)

        vectordb = Chroma.from_documents(
            documents=split_documents,
            embedding=embeddings_model,
            persist_directory=vector_db_persist_dir
        )
        vectordb.persist()
        print("Chroma DB created and persisted.")

        # 5. Develop a retriever
        print("Creating retriever...")
        retriever = vectordb.as_retriever(search_kwargs={"k": 5}) 

        # Initialize the Watsonx LLM for the QA bot
        print("Initializing Watsonx LLM for QA...")
        llm = WatsonxLLM(
            model_id=ModelTypes.MISTRAL_8X7B_INSTRUCT_V01, 
            url=watsonx_url,
            project_id=os.environ["WATSONX_PROJECT_ID"],
            api_key=os.environ["WATSONX_API_KEY"]
        )

        # 6. Construct the QA Chain
        print("Constructing RetrievalQA chain...")
        qa_chain = RetrievalQA.from_chain_type(
            llm=llm,
            chain_type="stuff", 
            retriever=retriever,
            return_source_documents=True 
        )
        print("QA chain initialized successfully!")
        return "Document processed and QA bot is ready! You can now ask questions."

    except Exception as e:
        print(f"Error initializing components: {e}")
        return f"Error: Could not initialize QA bot. {e}"

def ask_question(question):
    global qa_chain
    if qa_chain is None:
        return "Please upload and process a document first."

    try:
        print(f"Asking question: '{question}'")
        result = qa_chain.invoke({"query": question})
        answer = result["result"]
        return answer 
    except Exception as e:
        print(f"Error asking question: {e}")
        return f"Error getting answer: {e}"

# Gradio Interface setup
with gr.Blocks() as demo:
    gr.Markdown(
        """
        # 🤖 Quest Analytics RAG Assistant
        Upload a PDF document, and then ask questions about its content!
        """
    )
    with gr.Row():
        with gr.Column():
            pdf_upload_button = gr.File(label="Upload PDF Document", type="filepath")
            process_button = gr.Button("Process Document")
            status_output = gr.Textbox(label="Status", interactive=False)
        with gr.Column():
            question_input = gr.Textbox(label="Ask your question:", placeholder="E.g., What is this paper talking about?")
            answer_button = gr.Button("Get Answer")
            answer_output = gr.Textbox(label="Answer", interactive=False)

    process_button.click(initialize_components, inputs=pdf_upload_button, outputs=status_output)
    answer_button.click(ask_question, inputs=question_input, outputs=answer_output)

# demo.launch(share=False)

# %%
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_huggingface import HuggingFaceHub
from langchain.chains import RetrievalQA
import gradio as gr

os.environ["HUGGINGFACEHUB_API_TOKEN"] = "YOUR_HUGGING_FACE_TOKEN"

qa_chain = None
embeddings_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vector_db_persist_dir = "./chroma_db_huggingface"

def initialize_components(pdf_file_path):
    global qa_chain
    if not pdf_file_path:
        return "Please upload a PDF file."

    try:
        loader = PyPDFLoader(file_path=pdf_file_path)
        documents = loader.load()
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
        split_documents = text_splitter.split_documents(documents)

        # Create and persist the Chroma DB
        if os.path.exists(vector_db_persist_dir):
            import shutil
            shutil.rmtree(vector_db_persist_dir)
        vectordb = Chroma.from_documents(documents=split_documents, embedding=embeddings_model, persist_directory=vector_db_persist_dir)
        vectordb.persist()

        llm = HuggingFaceHub(
            repo_id="mistralai/Mixtral-8x7B-Instruct-v0.1",
            model_kwargs={"temperature": 0.5, "max_length": 512}
        )

        # Create the retriever and the QA chain
        retriever = vectordb.as_retriever(search_kwargs={"k": 3})
        qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=retriever, return_source_documents=True)
        return "Document processed and QA bot is ready!"
    except Exception as e:
        return f"Error: {e}"

def ask_question(question):
    global qa_chain
    if qa_chain is None:
        return "Please upload and process a document first."

    try:
        result = qa_chain.invoke({"query": question})
        return result["result"]
    except Exception as e:
        return f"Error getting answer: {e}"

# Gradio Interface setup
with gr.Blocks() as demo:
    gr.Markdown(
        """
        # 🤖 Open-Source RAG Assistant
        Upload a PDF document and ask questions about its content!
        """
    )
    with gr.Row():
        with gr.Column():
            pdf_upload_button = gr.File(label="Upload PDF Document", type="filepath")
            process_button = gr.Button("Process Document")
            status_output = gr.Textbox(label="Status", interactive=False)
        with gr.Column():
            question_input = gr.Textbox(label="Ask your question:", placeholder="E.g., What this paper is talking about?")
            answer_button = gr.Button("Get Answer")
            answer_output = gr.Textbox(label="Answer", interactive=False)

    process_button.click(initialize_components, inputs=pdf_upload_button, outputs=status_output)
    answer_button.click(ask_question, inputs=question_input, outputs=answer_output)

demo.launch()
